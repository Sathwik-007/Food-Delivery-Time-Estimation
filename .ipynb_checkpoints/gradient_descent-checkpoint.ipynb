# %% [markdown]
# # Learning

# %%
import numpy as np

# %%
X_raw = np.array([500, 1], [1000, 2], [1500, 2], [2000, 3], 
                 [2500, 3], [3000, 4], [4000, 4], [5000, 5]], dtype=float)
y = np.array([150, 200, 250, 300,
              320, 380, 450, 550], dtype=float)

# %%
X_raw
# Out:
# array([[5.0e+02, 1.0e+00],
#        [1.0e+03, 2.0e+00],
#        [1.5e+03, 2.0e+00],
#        [2.0e+03, 3.0e+00],
#        [2.5e+03, 3.0e+00],
#        [3.0e+03, 4.0e+00],
#        [4.0e+03, 4.0e+00],
#        [5.0e+03, 5.0e+00]])

# %%
np.zeros(X_raw.shape[1])
# Out:
# array([0., 0.])

# %%
y = y.reshape(-1, 1)
y
# Out:
# array([[150.],
#        [200.],
#        [250.],
#        [300.],
#        [320.],
#        [380.],
#        [450.],
#        [550.]])

# %%
def train(X, y, lr=0.0001, epochs=200):
    W = np.zeros((X.shape[1], 1))
    b = np.zeros((1, 1))
    losses = []
    for _ in range(epochs + 1):
        pred = X @ W + b
        err  = pred - y
        loss = (err**2).mean()
        losses.append(loss)
        W -= lr * (2/len(y)) * X.T @ err
        b -= lr * (2/len(y)) * err.mean()
        if _ % 50 == 0:
            print(f"Without norm — epoch {_}: {loss}")
    return losses

# %%
X_no_norm = X_raw.reshape(-1, 2)
losses_raw = train(X_no_norm, y, lr=0.000000001)
print(f"Without norm — epoch 0: {losses_raw[0]:.0f}, epoch 200: {losses_raw[-1]:.0f}")
# Out:
# Without norm — epoch 0: 120850.0
# Without norm — epoch 50: 26944.316055119423
# Without norm — epoch 100: 8109.594244562246
# Without norm — epoch 150: 4331.902174176907
# Without norm — epoch 200: 3574.2079584981843
# Without norm — epoch 0: 120850, epoch 200: 3574

# %%
X_norm = (X_raw - X_raw.mean(axis=0))/ (X_raw.std(axis=0))
losses_raw = train(X_norm, y, lr = 0.1)
# Out:
# Without norm — epoch 0: 120850.0
# Without norm — epoch 50: 8496.687598988836
# Without norm — epoch 100: 737.5542158375031
# Without norm — epoch 150: 108.1604315378885
# Without norm — epoch 200: 51.62440637265547

# %%
losses_raw
# Out:
# [np.float64(120850.0),
#  np.float64(106103.61822615608),
#  np.float64(97639.46228417967),
#  np.float64(91635.98195675795),
#  np.float64(86680.21172387851),
#  np.float64(82245.42248134235),
#  np.float64(78131.18814829337),
#  np.float64(74257.42659979463),
#  np.float64(70588.63218782128),
#  np.float64(67105.99316075354),
#  np.float64(63797.12177732259),
#  np.float64(60652.26304743809),
#  np.float64(57662.88698584489),
#  np.float64(54821.15817322687),
#  np.float64(52119.72861424099),
#  np.float64(49551.65009810605),
#  np.float64(47110.331077388786),
#  np.float64(44789.51045803384),
#  np.float64(42583.238120336726),
#  np.float64(40485.85840134186),
#  np.float64(38491.995128261246),
#  np.float64(36596.53766136903),
#  np.float64(34794.62772551661),
#  np.float64(33081.64692843286),
#  np.float64(31453.204908765394),
#  np.float64(29905.128074261298),
#  np.float64(28433.448897819515),
#  np.float64(27034.395742719254),
#  np.float64(25704.38319047288),
#  np.float64(24440.00284633059),
#  np.float64(23238.01459879552),
#  np.float64(22095.338310711515),
#  np.float64(21009.045920606965),
#  np.float64(19976.353934035273),
#  np.float64(18994.61628565516),
#  np.float64(18061.317553744866),
#  np.float64(17174.066509748853),
#  np.float64(16330.589986314688),
#  np.float64(15528.727048094664),
#  np.float64(14766.423450363156),
#  np.float64(14041.72637123875),
#  np.float64(117.50895205886795),
#  np.float64(114.24179441715401),
#  np.float64(111.12811320896333),
#  np.float64(108.1604315378885),
#  np.float64(105.33164037797994),
#  np.float64(102.63498042691326),
#  np.float64(100.06402485493044),
#  np.float64(97.6126629053467),
#  np.float64(95.27508430456666),
#  np.float64(93.04576444165036),
#  np.float64(90.91945027943302),
#  np.float64(88.89114696108085),
#  np.float64(86.95610507774613),
#  np.float64(85.10980856469115),
#  np.float64(83.34796319483613),
#  np.float64(81.66648564025624),
#  np.float64(80.06149307356806),
#  np.float64(78.52929328257036),
#  np.float64(77.06637527277954),
#  np.float64(75.66940033378943),
#  np.float64(74.33519354654734),
#  np.float64(73.06073570977911),
#  np.float64(71.84315566487395),
#  np.float64(70.67972299955116),
#  np.float64(69.56784111161767),
#  np.float64(68.50504061502829),
#  np.float64(67.48897307135752),
#  np.float64(66.51740503061676),
#  np.float64(65.58821236614014),
#  np.float64(64.69937488903003),
#  np.float64(63.84897122835085),
#  np.float64(63.035173963959906),
#  np.float64(62.25624499950072),
#  np.float64(61.51053116370275),
#  np.float64(60.796460028714584),
#  np.float64(60.11253593475991),
#  np.float64(59.45733621093152),
#  np.float64(58.82950758243551),
#  np.float64(58.22776275508841),
#  np.float64(57.650877168312405),
#  np.float64(57.09768590831141),
#  np.float64(56.5670807735246),
#  np.float64(56.05800748483516),
#  np.float64(55.56946303339342),
#  np.float64(55.10049315925759),
#  np.float64(54.650189954395984),
#  np.float64(54.21768958391518),
#  np.float64(53.80217011967283),
#  np.float64(53.40284948073171),
#  np.float64(53.01898347537994),
#  np.float64(52.64986393970432),
#  np.float64(52.29481696795112),
#  np.float64(51.95320123014535),
#  np.float64(51.62440637265547)]

# %%
X_no_norm.shape
# Out:
# (8, 2)

# %%
y.shape
# Out:
# (8, 1)

# %%
X_raw = X_raw.reshape(-1, 2)
X_raw
# Out:
# array([[5.0e+02, 1.0e+00],
#        [1.0e+03, 2.0e+00],
#        [1.5e+03, 2.0e+00],
#        [2.0e+03, 3.0e+00],
#        [2.5e+03, 3.0e+00],
#        [3.0e+03, 4.0e+00],
#        [4.0e+03, 4.0e+00],
#        [5.0e+03, 5.0e+00]])

# %%
W = np.zeros((X_raw.shape[1], 1))
b = np.zeros((1, 1))

# %%
W
# Out:
# array([[0.],
#        [0.]])

# %%
b
# Out:
# array([[0.]])

# %%
pred = X_raw @ W + b
pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
err = pred - y
err
# Out:
# array([[-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.],
#        [-150., -200., -250., -300., -320., -380., -450., -550.]])

# %%
loss = (err ** 2).mean()
loss
# Out:
# np.float64(120850.0)

# %%
losses = []

# %%
losses.append(loss)
losses
# Out:
# [np.float64(120850.0)]

# %%
W -= 0.00011 * (2/len(y)) * X_raw.T @ err
W
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 W -= 0.00011 * (2/len(y)) * X_raw.T @ err
#       2 W
#
# ValueError: non-broadcastable output operand with shape (2,1) doesn't match the broadcast shape (2,8)

# %% [raw]
# X_raw

# %%
-12.5 * 2/3
# Out:
# -8.333333333333334

# %% [markdown]
# # Practise

# %%
import numpy as np
